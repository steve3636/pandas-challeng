# %% [markdown]
# ### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
from pathlib import Path
import pandas as pd

# Define file paths
schools_complete_csv = Path("Resources/schools_complete.csv")
students_complete_csv = Path("Resources/students_complete.csv")


# Read School and Student Data File and store into Pandas DataFrames
schools_complete_df = pd.read_csv(schools_complete_csv)
students_complete_df = pd.read_csv(students_complete_csv)

# Combine the data into a single dataset.  
school_complete_df = pd.merge(schools_complete_df, students_complete_df, how="left", on=["school_name"])

school_complete_df
# Out:
#        School ID         school_name         type  size   budget  Student ID  \
# 0              0   Huang High School   Government  2917  1910635           0
# 1              0   Huang High School   Government  2917  1910635           1
# 2              0   Huang High School   Government  2917  1910635           2
# 3              0   Huang High School   Government  2917  1910635           3
# 4              0   Huang High School   Government  2917  1910635           4
# ...          ...                 ...          ...   ...      ...         ...
# 39165         14  Thomas High School  Independent  1635  1043130       39165
# 39166         14  Thomas High School  Independent  1635  1043130       39166
# 39167         14  Thomas High School  Independent  1635  1043130       39167
# 39168         14  Thomas High School  Independent  1635  1043130       39168
# 39169         14  Thomas High School  Independent  1635  1043130       39169
#
# ...

# %%
# Calculate the total number of schools
total_schools = schools_complete_df['school_name'].nunique()

# Calculate the total number of students
total_students = students_complete_df['Student ID'].nunique()

# Calculate the total budget
total_budget = schools_complete_df['budget'].sum()

# Calculate the average math and reading scores
average_math_score = students_complete_df['maths_score'].mean()
average_reading_score = students_complete_df['reading_score'].mean()

# Calculate the percentage of students with passing math and reading scores
passing_math_percentage = (students_complete_df['maths_score'] >= 50).mean() * 100
passing_reading_percentage = (students_complete_df['reading_score'] >= 50).mean() * 100

# Calculate the percentage of students who passed both math and reading
overall_passing_percentage = ((students_complete_df['maths_score'] >= 50) & (students_complete_df['reading_score'] >= 50)).mean() * 100


# Dictionary 
summary_data = {
    'Total Schools': total_schools,
    'Total Students': total_students,
    'Total Budget': total_budget,
    'Average Math Score': average_math_score],
    'Average Reading Score': [average_reading_score],
    '% Passing Math': [passing_math_percentage],
    '% Passing Reading': [passing_reading_percentage],
    '% Overall Passing': [overall_passing_percentage]
}

# DataFrame 
summary_df = pd.DataFrame(summary_data)

# Summary DataFrame with formatted percentages
formatted_summary_df = summary_df.style.format({
    'Total Budget': '${:,.2f}',
    'Average Math Score': '{:.2f}',
    'Average Reading Score': '{:.2f}',
    '% Passing Math': '{:.2f}%',
    '% Passing Reading': '{:.2f}%',
    '% Overall Passing': '{:.2f}%'
})

formatted_summary_df
# Out:
# <style type="text/css">
# </style>
# <table id="T_f4d0d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f4d0d_level0_col0" class="col_heading level0 col0" >Total Schools</th>
#       <th id="T_f4d0d_level0_col1" class="col_heading level0 col1" >Total Students</th>
#       <th id="T_f4d0d_level0_col2" class="col_heading level0 col2" >Total Budget</th>
#       <th id="T_f4d0d_level0_col3" class="col_heading level0 col3" >Average Math Score</th>
#       <th id="T_f4d0d_level0_col4" class="col_heading level0 col4" >Average Reading Score</th>
#       <th id="T_f4d0d_level0_col5" class="col_heading level0 col5" >% Passing Math</th>
#       <th id="T_f4d0d_level0_col6" class="col_heading level0 col6" >% Passing Reading</th>
#       <th id="T_f4d0d_level0_col7" class="col_heading level0 col7" >% Overall Passing</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f4d0d_level0_row0" class="row_heading level0 row0" >0</th>
# ...

# %% [markdown]
# ## Local Government Area Summary
#
# * Calculate the total number of schools
#
# * Calculate the total number of students
#
# * Calculate the total budget
#
# * Calculate the average maths score
#
# * Calculate the average reading score
#
# * Calculate the percentage of students with a passing maths score (50 or greater)
#
# * Calculate the percentage of students with a passing reading score (50 or greater)
#
# * Calculate the percentage of students who passed maths **and** reading (% Overall Passing)
#
# * Create a dataframe to hold the above results
#
# * Optional: give the displayed data cleaner formatting

# %%
# Out:
#    Total Schools Total Students    Total Budget  Average Maths Score  \
# 0             15         39,170  $24,649,428.00            70.338192
#
#    Average Reading Score  % Passing Maths  % Passing Reading  \
# 0              69.980138        86.078632          84.426857
#
#    % Overall Passing
# 0          72.808272

# %% [markdown]
# ## School Summary

# %% [markdown]
# * Create an overview table that summarises key metrics about each school, including:
#   * School Name
#   * School Type
#   * Total Students
#   * Total School Budget
#   * Per Student Budget
#   * Average Maths Score
#   * Average Reading Score
#   * % Passing Maths
#   * % Passing Reading
#   * % Overall Passing (The percentage of students that passed maths **and** reading.)
#
# * Create a dataframe to hold the above results

# %%
grouped_schools = students_complete_df.groupby(['school_name', 'type'])

# Calculate total students per school
total_students_per_school = summerised_schools['Student ID'].count()

# Calculate average math and reading scores per school
average_math_score_per_school = summerised_schools['maths_score'].mean()
average_reading_score_per_school = summerised_schools['reading_score'].mean()

# Calculate % passing math, reading, and overall passing per school
passing_math_per_school = (students_complete_df[students_complete_df['maths_score'] >= 50].groupby('school_name')['Student ID'].count() / total_students_per_school) * 100
passing_reading_per_school = (students_complete_df[students_complete_df['reading_score'] >= 50].groupby('school_name')['Student ID'].count() / total_students_per_school) * 100
overall_passing_per_school = (students_complete_df[(students_complete_df['maths_score'] >= 50) & (students_complete_df['reading_score'] >= 50)].groupby('school_name')['Student ID'].count() / total_students_per_school) * 100

# Combine the metrics into a summary DataFrame
school_summary_df = pd.DataFrame({
    'Total Students': total_students_per_school,
    'Average Math Score': average_math_score_per_school,
    'Average Reading Score': average_reading_score_per_school,
    '% Passing Math': passing_math_per_school,
    '% Passing Reading': passing_reading_per_school,
    '% Overall Passing': overall_passing_per_school
})
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[93], line 1
# ----> 1 grouped_schools = students_complete_df.groupby(['school_name', 'type'])
#       3 # Calculate total students per school
#       4 total_students_per_school = summerised_schools['Student ID'].count()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:8402, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    8399     raise TypeError("You have to supply one of 'by' and 'level'")
#    8400 axis = self._get_axis_number(axis)
# -> 8402 return DataFrameGroupBy(
#    8403     obj=self,
#    8404     keys=by,
#    8405     axis=axis,
#    8406     level=level,
#    8407     as_index=as_index,
#    8408     sort=sort,
#    8409     group_keys=group_keys,
#    8410     squeeze=squeeze,
#    8411     observed=observed,
#    8412     dropna=dropna,
# ...

# %%
# Merge with schools_complete_df to include school_type and budget information
school_summary_df = school_summary_df.merge(schools_complete_df[['school_name', 'type', 'budget']], left_index=True, right_on='school_name')

# Calculate per student budget
school_summary_df['Per Student Budget'] = school_summary_df['budget'] / school_summary_df['Total Students']

# %%
# Create the final overview table DataFrame
overview_table_df = school_summary_df[['school_name', 'type', 'Total Students', 'budget', 'Per Student Budget', 'Average Math Score', 'Average Reading Score', '% Passing Math', '% Passing Reading', '% Overall Passing']]

# Format columns as needed
overview_table_df['budget'] = overview_table_df['budget'].map('${:,.2f}'.format)
overview_table_df['Per Student Budget'] = overview_table_df['Per Student Budget'].map('${:,.2f}'.format)

# Display the overview table
overview_table_df
# Out:
#               school_name         type  Total Students         budget  \
# 7      Bailey High School   Government            4976  $3,124,928.00
# 6     Cabrera High School  Independent            1858  $1,081,356.00
# 1    Figueroa High School   Government            2949  $1,884,411.00
# 13       Ford High School   Government            2739  $1,763,916.00
# 4     Griffin High School  Independent            1468    $917,500.00
# 3   Hernandez High School   Government            4635  $3,022,020.00
# 8      Holden High School  Independent             427    $248,087.00
# 0       Huang High School   Government            2917  $1,910,635.00
# 12    Johnson High School   Government            4761  $3,094,650.00
# 9        Pena High School  Independent             962    $585,858.00
# 11  Rodriguez High School   Government            3999  $2,547,363.00
# 2     Shelton High School  Independent            1761  $1,056,600.00
# ...

# %%
# Out:
#                        School Type  Total Students Total School Budget  \
# Bailey High School      Government            4976       $3,124,928.00
# Cabrera High School    Independent            1858       $1,081,356.00
# Figueroa High School    Government            2949       $1,884,411.00
# Ford High School        Government            2739       $1,763,916.00
# Griffin High School    Independent            1468         $917,500.00
# Hernandez High School   Government            4635       $3,022,020.00
# Holden High School     Independent             427         $248,087.00
# Huang High School       Government            2917       $1,910,635.00
# Johnson High School     Government            4761       $3,094,650.00
# Pena High School       Independent             962         $585,858.00
# Rodriguez High School   Government            3999       $2,547,363.00
# Shelton High School    Independent            1761       $1,056,600.00
# ...

# %% [markdown]
# ## Top Performing Schools (By % Overall Passing)

# %% [markdown]
# * Sort and display the top five performing schools by % overall passing.

# %%
# Sort the overview_table_df by '% Overall Passing' in descending order
top_performing_schools = overview_table_df.sort_values(by='% Overall Passing', ascending=False)

# Display the top five performing schools
top_performing_schools.head()
# Out:
#               school_name         type  Total Students         budget  \
# 4     Griffin High School  Independent            1468    $917,500.00
# 6     Cabrera High School  Independent            1858  $1,081,356.00
# 7      Bailey High School   Government            4976  $3,124,928.00
# 10     Wright High School  Independent            1800  $1,049,400.00
# 11  Rodriguez High School   Government            3999  $2,547,363.00
#
#    Per Student Budget  Average Math Score  Average Reading Score  \
# 4             $625.00           71.788147              71.245232
# 6             $582.00           71.657158              71.359526
# 7             $628.00           72.352894              71.008842
# 10            $583.00           72.047222              70.969444
# 11            $637.00           72.047762              70.935984
#
#     % Passing Math  % Passing Reading  % Overall Passing
# 4        91.212534          88.487738          81.335150
# ...

# %%
# Out:
#                        School Type  Total Students Total School Budget  \
# Griffin High School    Independent            1468         $917,500.00
# Cabrera High School    Independent            1858       $1,081,356.00
# Bailey High School      Government            4976       $3,124,928.00
# Wright High School     Independent            1800       $1,049,400.00
# Rodriguez High School   Government            3999       $2,547,363.00
#
#                       Per Student Budget  Average Maths Score  \
# Griffin High School              $625.00            71.788147
# Cabrera High School              $582.00            71.657158
# Bailey High School               $628.00            72.352894
# Wright High School               $583.00            72.047222
# Rodriguez High School            $637.00            72.047762
#
#                        Average Reading Score  % Passing Maths  \
# Griffin High School                71.245232        91.212534
# ...

# %% [markdown]
# ## Bottom Performing Schools (By % Overall Passing)

# %% [markdown]
# * Sort and display the five worst-performing schools by % overall passing.

# %%
# Sort the overview_table_df by '% Overall Passing' in ascending order
worst_performing_schools = overview_table_df.sort_values(by='% Overall Passing')

# Display the five worst-performing schools
worst_performing_schools.head()
# Out:
#               school_name         type  Total Students         budget  \
# 3   Hernandez High School   Government            4635  $3,022,020.00
# 0       Huang High School   Government            2917  $1,910,635.00
# 12    Johnson High School   Government            4761  $3,094,650.00
# 5      Wilson High School  Independent            2283  $1,319,574.00
# 13       Ford High School   Government            2739  $1,763,916.00
#
#    Per Student Budget  Average Math Score  Average Reading Score  \
# 3             $652.00           68.874865              69.186408
# 0             $655.00           68.935207              68.910525
# 12            $650.00           68.843100              69.039277
# 5             $578.00           69.170828              68.876916
# 13            $644.00           69.091274              69.572472
#
#     % Passing Math  % Passing Reading  % Overall Passing
# 3        80.949299          81.877023          66.364617
# ...

# %%
# Out:
#                        School Type  Total Students Total School Budget  \
# Hernandez High School   Government            4635       $3,022,020.00
# Huang High School       Government            2917       $1,910,635.00
# Johnson High School     Government            4761       $3,094,650.00
# Wilson High School     Independent            2283       $1,319,574.00
# Ford High School        Government            2739       $1,763,916.00
#
#                       Per Student Budget  Average Maths Score  \
# Hernandez High School            $652.00            68.874865
# Huang High School                $655.00            68.935207
# Johnson High School              $650.00            68.843100
# Wilson High School               $578.00            69.170828
# Ford High School                 $644.00            69.091274
#
#                        Average Reading Score  % Passing Maths  \
# Hernandez High School              69.186408        80.949299
# ...

# %% [markdown]
# ## Maths Scores by Year

# %% [markdown]
# * Create a table that lists the average maths score for students of each year level (9, 10, 11, 12) at each school.
#
#   * Create a pandas series for each year. Hint: use a conditional statement.
#
#   * Group each series by school
#
#   * Combine the series into a dataframe
#
#   * Optional: give the displayed data cleaner formatting

# %%
# Create pandas series for each year level using conditional statements
average_math_9th = students_complete_df[students_complete_df['year'] == 9].groupby('school_name')['maths_score'].mean()
average_math_10th = students_complete_df[students_complete_df['year'] == 10].groupby('school_name')['maths_score'].mean()
average_math_11th = students_complete_df[students_complete_df['year'] == 11].groupby('school_name')['maths_score'].mean()
average_math_12th = students_complete_df[students_complete_df['year'] == 12].groupby('school_name')['maths_score'].mean()

# %%
# Out:
#                           Year 9    Year 10    Year 11    Year 12
# Bailey High School     72.493827  71.897498  72.374900  72.675097
# Cabrera High School    72.321970  72.437768  71.008299  70.604712
# Figueroa High School   68.477804  68.331586  68.811001  69.325282
# Ford High School       69.021609  69.387006  69.248862  68.617811
# Griffin High School    72.789731  71.093596  71.692521  71.469178
# Hernandez High School  68.586831  68.867156  69.154412  68.985075
# Holden High School     70.543307  75.105263  71.640777  73.409639
# Huang High School      69.081754  68.533246  69.431345  68.639316
# Johnson High School    69.469286  67.990220  68.637730  69.287393
# Pena High School       71.996364  72.396000  72.523438  71.187845
# Rodriguez High School  71.940722  71.779808  72.364811  72.154626
# Shelton High School    72.932075  72.506696  70.097087  72.331536
# Thomas High School     69.234273  70.057007  69.657831  69.369822
# ...

# %%
# Combine the series into a DataFrame
average_math_by_year_df = pd.DataFrame({
    '9th Grade': average_math_9th,
    '10th Grade': average_math_10th,
    '11th Grade': average_math_11th,
    '12th Grade': average_math_12th
})

# %%
# Display the DataFrame with cleaner formatting
average_math_by_year_df.style.format('{:.2f}')
# Out:
# <style type="text/css">
# </style>
# <table id="T_b5339">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b5339_level0_col0" class="col_heading level0 col0" >9th Grade</th>
#       <th id="T_b5339_level0_col1" class="col_heading level0 col1" >10th Grade</th>
#       <th id="T_b5339_level0_col2" class="col_heading level0 col2" >11th Grade</th>
#       <th id="T_b5339_level0_col3" class="col_heading level0 col3" >12th Grade</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >school_name</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b5339_level0_row0" class="row_heading level0 row0" >Bailey High School</th>
#       <td id="T_b5339_row0_col0" class="data row0 col0" >72.49</td>
# ...

# %% [markdown]
# ## Reading Score by Year

# %% [markdown]
# * Perform the same operations as above for reading scores

# %%
# Create pandas series for each year level using conditional statements
average_reading_9th = students_complete_df[students_complete_df['year'] == 9].groupby('school_name')['reading_score'].mean()
average_reading_10th = students_complete_df[students_complete_df['year'] == 10].groupby('school_name')['reading_score'].mean()
average_reading_11th = students_complete_df[students_complete_df['year'] == 11].groupby('school_name')['reading_score'].mean()
average_reading_12th = students_complete_df[students_complete_df['year'] == 12].groupby('school_name')['reading_score'].mean()

# %%
# Combine the series into a DataFrame
average_reading_by_year_df = pd.DataFrame({
    '9th Grade': average_reading_9th,
    '10th Grade': average_reading_10th,
    '11th Grade': average_reading_11th,
    '12th Grade': average_reading_12th
})

# %%
# Display the DataFrame with cleaner formatting
average_reading_by_year_df.style.format('{:.2f}')
# Out:
# <style type="text/css">
# </style>
# <table id="T_dcd4d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_dcd4d_level0_col0" class="col_heading level0 col0" >9th Grade</th>
#       <th id="T_dcd4d_level0_col1" class="col_heading level0 col1" >10th Grade</th>
#       <th id="T_dcd4d_level0_col2" class="col_heading level0 col2" >11th Grade</th>
#       <th id="T_dcd4d_level0_col3" class="col_heading level0 col3" >12th Grade</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >school_name</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dcd4d_level0_row0" class="row_heading level0 row0" >Bailey High School</th>
#       <td id="T_dcd4d_row0_col0" class="data row0 col0" >70.90</td>
# ...

# %% [markdown]
# ## Scores by School Spending

# %% [markdown]
# * Create a table that breaks down school performances based on average Spending Ranges (Per Student). Use 4 reasonable bins to group school spending. Include in the table each of the following:
#   * Average Maths Score
#   * Average Reading Score
#   * % Passing Maths
#   * % Passing Reading
#   * Overall Passing Rate (Average of the above two)

# %%
# Out:
#                                Average Maths Score  Average Reading Score  \
# Spending Ranges (Per Student)
# <$585                                        71.36                  70.72
# $585-630                                     72.07                  71.03
# $630-645                                     69.85                  69.84
# $645-680                                     68.88                  69.05
#
#                                % Passing Maths  % Passing Reading  \
# Spending Ranges (Per Student)
# <$585                                    88.84              86.39
# $585-630                                 91.52              87.29
# $630-645                                 84.69              83.76
# $645-680                                 81.57              81.77
#
#                                % Overall Passing
# Spending Ranges (Per Student)
# <$585                                      76.72
# $585-630                                   79.88
# ...

# %% [markdown]
# ## Scores by School Size

# %% [markdown]
# * Perform the same operations as above, based on school size.

# %%
# Out:
#                     Average Maths Score  Average Reading Score  \
# School Size
# Small (<1000)                 72.335748              71.636864
# Medium (1000-2000)            71.421650              70.720164
# Large (2000-5000)             69.751809              69.576052
#
#                     % Passing Maths  % Passing Reading  % Overall Passing
# School Size
# Small (<1000)             90.806867          87.557513          79.066348
# Medium (1000-2000)        89.846560          86.714149          78.039785
# Large (2000-5000)         84.252804          83.301185          70.293507

# %% [markdown]
# ## Scores by School Type

# %% [markdown]
# * Perform the same operations as above, based on school type

# %%
# Out:
#              Average Maths Score  Average Reading Score  % Passing Maths  \
# School Type
# Government             69.834806              69.675929        84.462375
# Independent            71.368822              70.718933        89.204043
#
#              % Passing Reading  % Overall Passing
# School Type
# Government           83.587562          70.698993
# Independent          86.247789          76.973340
